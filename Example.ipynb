# %%
from summarynb import show, image, csv, indexed_csv, chunks

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ```
# > summarynb install
# installed
#
# > summarynb mark Example.ipynb
# Registered notebook for autorun. Make sure git pre-commit hook is installed by running: summarynb install
#
# > summarynb list
#         filename  exists
# 0  Example.ipynb    True
#
# # test run
# > summarynb run
# Running summary notebooks. Skip this with --no-verify
# Example.ipynb
# ran hook
#
# > git commit ...
# ```

# %% [markdown]
# # Basics: single image

# %%
show("tests/data/run_1.png")
# Out:
# <table><tr><td align="center"><img src="tests/data/run_1.png" style="max-width: 800px; max-height: 800px;" /></td></tr></table>

# %% [markdown]
# # Make tables

# %%
show([["tests/data/run_1.png", "tests/data/run_1.csv"]])
# Out:
# <table><tr><td align="center"><img src="tests/data/run_1.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>Run 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>slope</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>intercept</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>r_value</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>p_value</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>std_err</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table></td></tr></table>

# %%
show(
    [
        ["tests/data/run_1.png", "tests/data/run_1.csv"],
        ["tests/data/run_2.png", "tests/data/run_2.csv"],
    ]
)
# Out:
# <table><tr><td align="center"><img src="tests/data/run_1.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>Run 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>slope</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>intercept</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>r_value</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>p_value</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>std_err</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table></td></tr>
# <tr><td align="center"><img src="tests/data/run_2.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>Run 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>slope</td>
#       <td>1.006883e+01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>intercept</td>
#       <td>2.541054e+00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>r_value</td>
#       <td>9.862271e-01</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>p_value</td>
#       <td>2.121859e-78</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>std_err</td>
#       <td>1.705751e-01</td>
#     </tr>
#   </tbody>
# </table></td></tr></table>

# %% [markdown]
# # Helpers

# %%
show(csv("tests/data/run_summary.tsv", sep="\t", index_col=0))
# Out:
# <table><tr><td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 1</th>
#       <th>Run 2</th>
#       <th>Run 3</th>
#       <th>Run 4</th>
#       <th>Run 5</th>
#       <th>Run 6</th>
#       <th>Run 7</th>
#       <th>Run 8</th>
#       <th>Run 9</th>
#       <th>Run 10</th>
#       <th>Run 11</th>
#       <th>Run 12</th>
#       <th>Run 13</th>
#       <th>Run 14</th>
#       <th>Run 15</th>
#       <th>Run 16</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>10.0</td>
#       <td>1.006883e+01</td>
#       <td>9.984474e+00</td>
#       <td>7.536904e+00</td>
#       <td>-1.000000e+01</td>
#       <td>-9.859769e+00</td>
#       <td>-9.876179e+00</td>
#       <td>-9.989528e+00</td>
#       <td>1.000000e-01</td>
#       <td>0.338588</td>
#       <td>0.064135</td>
#       <td>-0.265716</td>
#       <td>-1.000000e-01</td>
#       <td>-0.141837</td>
#       <td>0.120874</td>
#       <td>0.236470</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>0.0</td>
#       <td>2.541054e+00</td>
#       <td>4.955526e+00</td>
#       <td>2.538343e+01</td>
#       <td>4.440892e-16</td>
#       <td>2.576564e+00</td>
#       <td>4.546295e+00</td>
#       <td>2.591503e+01</td>
#       <td>4.336809e-18</td>
#       <td>2.390523</td>
#       <td>5.137810</td>
#       <td>24.767195</td>
#       <td>-5.204170e-18</td>
#       <td>2.330583</td>
#       <td>5.658887</td>
#       <td>23.683839</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>1.0</td>
#       <td>9.862271e-01</td>
#       <td>9.580257e-01</td>
#       <td>4.924700e-01</td>
#       <td>-1.000000e+00</td>
#       <td>-9.873668e-01</td>
#       <td>-9.496076e-01</td>
#       <td>-6.350839e-01</td>
#       <td>1.000000e+00</td>
#       <td>0.245944</td>
#       <td>0.022460</td>
#       <td>-0.021416</td>
#       <td>-1.000000e+00</td>
#       <td>-0.089953</td>
#       <td>0.038750</td>
#       <td>0.015881</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>0.0</td>
#       <td>2.121859e-78</td>
#       <td>5.607411e-55</td>
#       <td>1.946173e-07</td>
#       <td>0.000000e+00</td>
#       <td>3.165610e-80</td>
#       <td>3.552349e-51</td>
#       <td>1.279674e-12</td>
#       <td>0.000000e+00</td>
#       <td>0.013643</td>
#       <td>0.824467</td>
#       <td>0.832506</td>
#       <td>0.000000e+00</td>
#       <td>0.373450</td>
#       <td>0.701892</td>
#       <td>0.875381</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>0.0</td>
#       <td>1.705751e-01</td>
#       <td>3.018117e-01</td>
#       <td>1.345500e+00</td>
#       <td>0.000000e+00</td>
#       <td>1.598348e-01</td>
#       <td>3.292972e-01</td>
#       <td>1.227347e+00</td>
#       <td>3.010489e-10</td>
#       <td>0.134795</td>
#       <td>0.288380</td>
#       <td>1.253062</td>
#       <td>3.010489e-10</td>
#       <td>0.158633</td>
#       <td>0.314866</td>
#       <td>1.503909</td>
#     </tr>
#   </tbody>
# </table></td></tr></table>

# %%
show(
    [
        ["tests/data/run_1.png", indexed_csv("tests/data/run_1.csv")],
        [image("tests/data/run_2.png"), indexed_csv("tests/data/run_2.csv")],
    ],
    max_width=1200,
)
# Out:
# <table><tr><td align="center"><img src="tests/data/run_1.png" style="max-width: 1200px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table></td></tr>
# <tr><td align="center"><img src="tests/data/run_2.png" style="max-width: 1200px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>1.006883e+01</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>2.541054e+00</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>9.862271e-01</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>2.121859e-78</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>1.705751e-01</td>
#     </tr>
#   </tbody>
# </table></td></tr></table>

# %%
show(
    chunks(
        entries=[
            [
                image("tests/data/run_%d.png" % (i + 1)),
                indexed_csv("tests/data/run_%d.csv" % (i + 1)),
            ]
            for i in range(16)
        ],
        shape=4,
    )
)
# Out:
# <table><tr><td align="center"><img src="tests/data/run_1.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table></td>
# <td align="center"><img src="tests/data/run_2.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>1.006883e+01</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>2.541054e+00</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>9.862271e-01</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>2.121859e-78</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>1.705751e-01</td>
#     </tr>
#   </tbody>
# </table></td></tr>
# <tr><td align="center"><img src="tests/data/run_3.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>9.984474e+00</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>4.955526e+00</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>9.580257e-01</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>5.607411e-55</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>3.018117e-01</td>
#     </tr>
#   </tbody>
# </table></td>
# <td align="center"><img src="tests/data/run_4.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>7.536904e+00</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>2.538343e+01</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>4.924700e-01</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>1.946173e-07</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>1.345500e+00</td>
#     </tr>
#   </tbody>
# </table></td></tr>
# <tr><td align="center"><img src="tests/data/run_5.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>-1.000000e+01</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>4.440892e-16</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>-1.000000e+00</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>0.000000e+00</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>0.000000e+00</td>
#     </tr>
#   </tbody>
# </table></td>
# <td align="center"><img src="tests/data/run_6.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>-9.859769e+00</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>2.576564e+00</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>-9.873668e-01</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>3.165610e-80</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>1.598348e-01</td>
#     </tr>
#   </tbody>
# </table></td></tr>
# <tr><td align="center"><img src="tests/data/run_7.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>-9.876179e+00</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>4.546295e+00</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>-9.496076e-01</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>3.552349e-51</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>3.292972e-01</td>
#     </tr>
#   </tbody>
# </table></td>
# <td align="center"><img src="tests/data/run_8.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>-9.989528e+00</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>2.591503e+01</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>-6.350839e-01</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>1.279674e-12</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>1.227347e+00</td>
#     </tr>
#   </tbody>
# </table></td></tr>
# <tr><td align="center"><img src="tests/data/run_9.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>1.000000e-01</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>4.336809e-18</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>1.000000e+00</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>0.000000e+00</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>3.010489e-10</td>
#     </tr>
#   </tbody>
# </table></td>
# <td align="center"><img src="tests/data/run_10.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>0.338588</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>2.390523</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>0.245944</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>0.013643</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>0.134795</td>
#     </tr>
#   </tbody>
# </table></td></tr>
# <tr><td align="center"><img src="tests/data/run_11.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 11</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>0.064135</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>5.137810</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>0.022460</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>0.824467</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>0.288380</td>
#     </tr>
#   </tbody>
# </table></td>
# <td align="center"><img src="tests/data/run_12.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Run 12</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>slope</th>
#       <td>-0.265716</td>
#     </tr>
#     <tr>
#       <th>intercept</th>
#       <td>24.767195</td>
#     </tr>
#     <tr>
#       <th>r_value</th>
#       <td>-0.021416</td>
#     </tr>
#     <tr>
#       <th>p_value</th>
#       <td>0.832506</td>
#     </tr>
#     <tr>
#       <th>std_err</th>
#       <td>1.253062</td>
#     </tr>
#   </tbody>
# </table></td></tr>
# <tr><td align="center"><img src="tests/data/run_13.png" style="max-width: 800px; max-height: 800px;" /></td>
# <td align="center"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>R
